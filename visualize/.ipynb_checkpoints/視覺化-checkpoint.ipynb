# %% [markdown]
# # 引入csv

# %%
import pandas as pd

# %%
df = pd.read_csv("Data_graphing.csv")

# %%
df.head()
# Out:
#    Unnamed: 0          Date_format  IsOfficialReport  Latitude  Longitude  \
# 0           0  2019-05-08 23:48:47               1.0    24.820    122.490
# 1           1  2019-05-08 23:49:28               0.0    37.404   -122.075
# 2           2  2019-05-08 23:56:55               0.0    25.048    121.532
# 3           3  2019-05-09 00:43:35               0.0    25.048    121.532
# 4           4  2019-05-10 21:49:30               1.0    24.500    121.920
#
#     震度  YouWin
# 0  2.0     NaN
# 1  NaN     1.0
# 2  NaN     0.0
# 3  NaN     0.0
# 4  3.0     NaN

# %% [markdown]
# # 地圖視覺化試做 -- 使用Folium

# %%
import folium

# %%
# 設定
center_pos = [23.583234,120.5825975]

fmap = folium.Map(location = center_pos, zoom_start = 6.5)
#fmap.add_child(folium.Marker(location=[df['Latitude'][2],df['Longitude'][2]], popup='center'))

# %%
earthquake = folium.Marker(location=[df['Latitude'][0],df['Longitude'][0]], popup='<b>center<b>',
                                    icon=folium.Icon(color='red'))
m2 = folium.Marker(location=[df['Latitude'][1],df['Longitude'][1]],
                   popup='<i>first one</i>',
                   icon=folium.Icon(icon='phone', # Icon類型
                                    color='yellow', # Marker顏色
                                    prefix='fa')) # 使用Font Awesome Icons
m3 = folium.Marker(location=[df['Latitude'][2],df['Longitude'][2]],
                   icon=folium.Icon(icon='phone', # Icon類型
                                    color='purple', # Marker顏色
                                    prefix='fa')) # 使用Font Awesome Icons
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: color argument of Icon should be one of: {'purple', 'pink', 'red', 'darkred', 'orange', 'beige', 'lightblue', 'white', 'darkblue', 'gray', 'darkgreen', 'black', 'green', 'lightgray', 'cadetblue', 'blue', 'darkpurple', 'lightgreen', 'lightred'}.
#   import sys

# %%
fmap.add_child(child=earthquake)
fmap.add_child(child=m2)
fmap.add_child(child=m3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 標準化製圖流程

# %%
names = locals()  # 設定local變數命名每張圖
counter = 0  # 地震計數器
center_pos = [23.583234,120.5825975]  # 為了使地圖置中


for i in range(723): # 等等改回來723
    if df['IsOfficialReport'][i] == 1:  # 公告地震
        counter += 1
        names["fmap_%s" %counter] = folium.Map(location = center_pos, zoom_start = 6.5)
        Popup = 'Seismic intensity: ' + str(df['震度'][i])
        earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup=Popup,
                                    icon=folium.Icon(icon='star',color='red'))
        names["fmap_%s" %counter].add_child(child=earthquake)
    else:
        try:
            if df["YouWin"][i] == 1:
                m1 = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]],
                       popup='<i>Winner</i>',
                       icon=folium.Icon(icon='phone', # Icon類型
                                        color='cadetblue', # Marker顏色
                                        prefix='fa')) # 使用Font Awesome Icons
                names["fmap_%s" %counter].add_child(child=m1)
            else:
                m2 = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]],
                       icon=folium.Icon(icon='phone', # Icon類型
                                        color='purple', # Marker顏色
                                        prefix='fa')) # 使用Font Awesome Icons
                if m2.location != m1.location:
                    names["fmap_%s" %counter].add_child(child=m2)
        except:
            continue

# %%
fmap_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 試做使用者介面

# %%
# !pip install -U ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 455 kB/s
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in /Applications/anaconda3/lib/python3.6/site-packages (from ipywidgets) (4.3.2)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in /Applications/anaconda3/lib/python3.6/site-packages (from ipywidgets) (4.4.0)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in /Applications/anaconda3/lib/python3.6/site-packages (from ipywidgets) (6.4.0)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in /Applications/anaconda3/lib/python3.6/site-packages (from ipywidgets) (4.8.2)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 621 kB/s
# Requirement already satisfied, skipping upgrade: ipython_genutils in /Applications/anaconda3/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets) (0.2.0)
# Requirement already satisfied, skipping upgrade: six in /Applications/anaconda3/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets) (1.11.0)
# Requirement already satisfied, skipping upgrade: decorator in /Applications/anaconda3/lib/python3.6/site-packages (from traitlets>=4.3.1->ipywidgets) (4.3.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /Applications/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets) (2.6.0)
# Requirement already satisfied, skipping upgrade: jupyter_core in /Applications/anaconda3/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied, skipping upgrade: pygments in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.2.0)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.5.0)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (39.1.0)
# Requirement already satisfied, skipping upgrade: simplegeneric>0.8 in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.8.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.0.0,>=1.0.15 in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (1.0.15)
# Requirement already satisfied, skipping upgrade: appnope; sys_platform == "darwin" in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied, skipping upgrade: backcall in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.12.0)
# Requirement already satisfied, skipping upgrade: pickleshare in /Applications/anaconda3/lib/python3.6/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.4)
# Requirement already satisfied, skipping upgrade: jupyter_client in /Applications/anaconda3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.2.3)
# Requirement already satisfied, skipping upgrade: tornado>=4.0 in /Applications/anaconda3/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.0.2)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in /Applications/anaconda3/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (5.5.0)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /Applications/anaconda3/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.5.2)
# Requirement already satisfied, skipping upgrade: wcwidth in /Applications/anaconda3/lib/python3.6/site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.7)
# Requirement already satisfied, skipping upgrade: parso>=0.2.0 in /Applications/anaconda3/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=13 in /Applications/anaconda3/lib/python3.6/site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets) (17.0.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /Applications/anaconda3/lib/python3.6/site-packages (from jupyter_client->ipykernel>=4.5.1->ipywidgets) (2.7.3)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /Applications/anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.1)
# Requirement already satisfied, skipping upgrade: nbconvert in /Applications/anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (5.3.1)
# Requirement already satisfied, skipping upgrade: jinja2 in /Applications/anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.10)
# Requirement already satisfied, skipping upgrade: Send2Trash in /Applications/anaconda3/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied, skipping upgrade: mistune>=0.7.4 in /Applications/anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.3)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /Applications/anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.2.3)
# Requirement already satisfied, skipping upgrade: bleach in /Applications/anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.1.3)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /Applications/anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.2)
# Requirement already satisfied, skipping upgrade: testpath in /Applications/anaconda3/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /Applications/anaconda3/lib/python3.6/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.0)
# Requirement already satisfied, skipping upgrade: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in /Applications/anaconda3/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.0.1)
# Requirement already satisfied, skipping upgrade: webencodings in /Applications/anaconda3/lib/python3.6/site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Installing collected packages: widgetsnbextension, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.2.1
#     Uninstalling widgetsnbextension-3.2.1:
#       Successfully uninstalled widgetsnbextension-3.2.1
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.2.1
#     Uninstalling ipywidgets-7.2.1:
#       Successfully uninstalled ipywidgets-7.2.1
# Successfully installed ipywidgets-7.5.1 widgetsnbextension-3.5.1

# %%
#from IPython.html.widgets import interact
from ipywidgets import interact

# %%
def f(x):
    return names["fmap_%s" %str(x)]

# %%
interact(f, x=(1, 91))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <function __main__.f(x)>

# %% [markdown]
# # 觀察台灣地震分佈
# * 震度由6到1分別是：紅橙黃綠藍紫

# %%
allEarthquake = folium.Map(location = center_pos, zoom_start = 6.5)
for i in range(723):
    if df['IsOfficialReport'][i] == 1:
        if df['震度'][i] == 1:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                        icon=folium.Icon(icon='star',color='purple'))
            allEarthquake.add_child(child=earthquake)
        elif df['震度'][i] == 2:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                        icon=folium.Icon(icon='star',color='blue'))
            allEarthquake.add_child(child=earthquake)
        elif df['震度'][i] == 3:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                    icon=folium.Icon(icon='star',color='green'))
            allEarthquake.add_child(child=earthquake)
        elif df['震度'][i] == 4:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                    icon=folium.Icon(icon='star',color='yellow'))
            allEarthquake.add_child(child=earthquake)
        elif df['震度'][i] == 5:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                    icon=folium.Icon(icon='star',color='orange'))
            allEarthquake.add_child(child=earthquake)
        elif df['震度'][i] == 6:
            earthquake = folium.Marker(location=[df['Latitude'][i],df['Longitude'][i]], popup='<b>center<b>',
                                    icon=folium.Icon(icon='star',color='red'))
            allEarthquake.add_child(child=earthquake)
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: color argument of Icon should be one of: {'purple', 'pink', 'red', 'darkred', 'orange', 'beige', 'lightblue', 'white', 'darkblue', 'gray', 'darkgreen', 'black', 'green', 'lightgray', 'cadetblue', 'blue', 'darkpurple', 'lightgreen', 'lightred'}.

# %%
allEarthquake
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 對所有地震建立字典
# * {'時間'：地圖}

# %%
d = {}
datelist = []
counter = 0
for i in range(723):
    if df['IsOfficialReport'][i] == 1:
        counter += 1
        d[df['Date_format'][i]] = {}
        d[df['Date_format'][i]]['map'] = names["fmap_%s" %counter]
        datelist.append(df['Date_format'][i])

# %%
def findmap(time):
    return d[time]['map']

# %% [markdown]
# # 最終版

# %%
interact(findmap, time=datelist)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <function __main__.findmap(time)>
